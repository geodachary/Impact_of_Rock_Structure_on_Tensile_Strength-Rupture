# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.tri as tri

df = pd.read_csv("selected_all_samples.csv", delimiter=",", header=0, index_col=0)

expected_columns = [
    'Rock_type',
    'Angle',
    'Diameter_mm',
    'Thickness_mm',
    'H/D_ratio',
    'Area_mm^2',
    'Volume_mm^3',
    'Bulk_Density',
    'Porosity_percent',
    'Density',
    'Load_(KN)',
    'Tensile_strength_Mpa',
    'Mass',
    'Modulus_of_Elasticity',
    'Lateral_strain',
    'Axial_strain',
    'Poisson_Ratio',
    'Shear_Modulus',
    'Radians',
    'UCS_(Mpa)',
    'Cohesion',
    'Friction_Angle'
]

# %%
print(df['Rock_type'].unique())
print(df['Angle'].unique())
# Out:
# ['Augen gneiss' 'Psammitic schist' nan]
# [ 0. 15. 30. 45. 60. 75. 90. nan]

# %%
df
# Out:
#         Rock_type  Angle  Diameter_mm  Thickness_mm  H/D_ratio  Area_mm^2  \
# SN
# 1.0  Augen gneiss    0.0         51.0          23.0       0.45    3685.09
# 2.0  Augen gneiss    0.0         51.0          24.0       0.47    3845.31
# 3.0  Augen gneiss    0.0         51.0          27.0       0.53    4325.97
# 4.0  Augen gneiss    0.0         51.0          22.5       0.44    3604.98
# 5.0  Augen gneiss    0.0         51.0          24.5       0.48    3925.42
# ..            ...    ...          ...           ...        ...        ...
# NaN           NaN    NaN          NaN           NaN        NaN        NaN
# NaN           NaN    NaN          NaN           NaN        NaN        NaN
# NaN           NaN    NaN          NaN           NaN        NaN        NaN
# NaN           NaN    NaN          NaN           NaN        NaN        NaN
# NaN           NaN    NaN          NaN           NaN        NaN        NaN
#
#      Volume_mm^3  Bulk_Density  Porosity_percent  Density  ...    Mass  \
# SN                                                         ...
# 1.0     46984.87          2.78              1.45     2.82  ...  130.62
# 2.0     49027.69          2.84              0.93     2.87  ...  139.24
# 3.0     55156.16          2.76              1.42     2.80  ...  152.23
# 4.0     45963.46          2.88              0.80     2.90  ...  132.37
# 5.0     50049.11          2.81              1.34     2.85  ...  140.64
# ..           ...           ...               ...      ...  ...     ...
# NaN          NaN           NaN               NaN      NaN  ...     NaN
# NaN          NaN           NaN               NaN      NaN  ...     NaN
# NaN          NaN           NaN               NaN      NaN  ...     NaN
# NaN          NaN           NaN               NaN      NaN  ...     NaN
# NaN          NaN           NaN               NaN      NaN  ...     NaN
#
#      Axial_strain  Lateral_strain  Modulus_of_Elasticity  Poisson_Ratio  \
# SN
# 1.0      0.001492        0.000388                   34.5           0.26
# 2.0      0.001505        0.000391                   39.0           0.26
# 3.0      0.001533        0.000398                   40.0           0.26
# 4.0      0.001496        0.000389                   39.5           0.26
# 5.0      0.001456        0.000379                   39.0           0.26
# ..            ...             ...                    ...            ...
# NaN           NaN             NaN                    NaN            NaN
# NaN           NaN             NaN                    NaN            NaN
# NaN           NaN             NaN                    NaN            NaN
# NaN           NaN             NaN                    NaN            NaN
# NaN           NaN             NaN                    NaN            NaN
#
#      Shear_Modulus  Radians  UCS_(Mpa)  Cohesion  Friction_Angle
# SN
# 1.0        13.6905      0.0      51.46     15.22           37.89
# 2.0        15.4762      0.0      58.70     15.22           37.89
# 3.0        15.8730      0.0      61.30     15.22           37.89
# 4.0        15.6746      0.0      59.10     15.22           37.89
# 5.0        15.4762      0.0      56.80     15.22           37.89
# ..             ...      ...        ...       ...             ...
# NaN            NaN      NaN        NaN       NaN             NaN
# NaN            NaN      NaN        NaN       NaN             NaN
# NaN            NaN      NaN        NaN       NaN             NaN
# NaN            NaN      NaN        NaN       NaN             NaN
# NaN            NaN      NaN        NaN       NaN             NaN
#
# [76 rows x 22 columns]

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.tri as tri

# --------------------------------------------------
# Load data
# --------------------------------------------------

df = pd.read_csv(
    "selected_all_samples.csv",
    delimiter=",",
    header=0,
    index_col=0
)

# --------------------------------------------------
# Expected columns
# --------------------------------------------------

expected_columns = [
    'Rock_type',
    'Angle',
    'Diameter_mm',
    'Thickness_mm',
    'H/D_ratio',
    'Area_mm^2',
    'Volume_mm^3',
    'Bulk_Density',
    'Porosity_percent',
    'Density',
    'Load_(KN)',
    'Tensile_strength_Mpa',
    'Mass',
    'Modulus_of_Elasticity',
    'Lateral_strain',
    'Axial_strain',
    'Poisson_Ratio',
    'Shear_Modulus',
    'Radians',
    'UCS_(Mpa)',
    'Cohesion',
    'Friction_Angle'
]

# --------------------------------------------------
# Check data
# --------------------------------------------------

print("Rock types:")
print(df['Rock_type'].unique())

print("\nAngles:")
print(np.sort(df['Angle'].unique()))

print("\nOriginal dataframe shape:")
print(df.shape)

# --------------------------------------------------
# Calculate mean for each Rock_type and Angle
# --------------------------------------------------

mean_df = (
    df.groupby(['Rock_type', 'Angle'], as_index=False)
      .mean(numeric_only=True)
      .sort_values(['Rock_type', 'Angle'])
      .reset_index(drop=True)
)

# --------------------------------------------------
# Add SN column as first column
# --------------------------------------------------

mean_df.insert(
    0,
    'SN',
    np.arange(1, len(mean_df) + 1)
)

# --------------------------------------------------
# Display results
# --------------------------------------------------

print("\nMean data based on Rock Type and Angle:")
print(mean_df)

print("\nMean dataframe shape:")
print(mean_df.shape)

# --------------------------------------------------
# Separate the two rock types
# --------------------------------------------------

augen_mean = (
    mean_df[mean_df['Rock_type'] == 'Augen Gneiss']
    .reset_index(drop=True)
)

psammitic_mean = (
    mean_df[mean_df['Rock_type'] == 'Psammitic Schist']
    .reset_index(drop=True)
)

print("\nAugen Gneiss mean data:")
print(augen_mean)

print("\nPsammitic Schist mean data:")
print(psammitic_mean)

print("\nNumber of Augen Gneiss mean rows:", len(augen_mean))
print("Number of Psammitic Schist mean rows:", len(psammitic_mean))

# --------------------------------------------------
# Save results to CSV/ Excel
# --------------------------------------------------

output_file = "tensile_samples_data.csv"

mean_df.to_csv(
    output_file,
    index=False
)

print(f"\nMean data successfully saved to: {output_file}")
# Out:
# Rock types:
# ['Augen gneiss' 'Psammitic schist' nan]
#
# Angles:
# [ 0. 15. 30. 45. 60. 75. 90. nan]
#
# Original dataframe shape:
# (76, 22)
#
# Mean data based on Rock Type and Angle:
#     SN         Rock_type  Angle  Diameter_mm  Thickness_mm  H/D_ratio  \
# 0    1      Augen gneiss    0.0         51.0     24.200000   0.474000
# 1    2      Augen gneiss   15.0         51.0     23.200000   0.454000
# 2    3      Augen gneiss   30.0         51.0     23.200000   0.454000
# 3    4      Augen gneiss   45.0         51.0     22.000000   0.430000
# 4    5      Augen gneiss   60.0         51.0     21.333333   0.416667
# 5    6      Augen gneiss   75.0         51.0     23.875000   0.467500
# 6    7      Augen gneiss   90.0         51.0     20.250000   0.395000
# 7    8  Psammitic schist    0.0         51.0     22.333333   0.436667
# 8    9  Psammitic schist   15.0         51.0     22.666667   0.443333
# 9   10  Psammitic schist   30.0         51.0     22.666667   0.443333
# 10  11  Psammitic schist   45.0         51.0     21.666667   0.423333
# 11  12  Psammitic schist   60.0         51.0     23.000000   0.450000
# 12  13  Psammitic schist   75.0         51.0     22.000000   0.430000
# 13  14  Psammitic schist   90.0         51.0     22.666667   0.443333
#
#       Area_mm^2  Volume_mm^3  Bulk_Density  Porosity_percent  ...        Mass  \
# 0   3877.354000   49436.2580      2.814000          1.188000  ...  139.020000
# 1   3717.132000   47393.4380      2.824000          1.150000  ...  133.950000
# 2   3717.132000   47393.4380      2.802000          1.224000  ...  132.862000
# 3   3524.867500   44942.0500      2.857500          0.985000  ...  128.285000
# 4   3418.056667   43580.1700      2.780000          1.400000  ...  121.196667
# 5   3825.282500   48772.3425      2.845000          1.055000  ...  138.915000
# 6   3244.477500   41367.1150      2.802500          1.255000  ...  115.962500
# 7   3578.276667   45622.9900      2.716667          1.893333  ...  123.936667
# 8   3631.683333   46303.9300      2.740000          1.696667  ...  126.920000
# 9   3631.683333   46303.9300      2.750000          1.673333  ...  127.376667
# 10  3471.463333   44261.1100      2.716667          1.876667  ...  120.316667
# 11  3685.090000   46984.8700      2.753333          1.416667  ...  129.340000
# 12  3524.870000   44942.0500      2.757500          1.430000  ...  123.947500
# 13  3631.683333   46303.9300      2.730000          1.640000  ...  126.450000
#
#     Axial_strain  Lateral_strain  Modulus_of_Elasticity  Poisson_Ratio  \
# 0       0.001496        0.000389              38.400000         0.2600
# 1       0.001364        0.000347              37.318000         0.2540
# 2       0.001085        0.000265              38.810000         0.2440
# 3       0.001162        0.000270              41.647500         0.2325
# 4       0.001069        0.000235              45.766667         0.2200
# 5       0.001228        0.000264              49.967500         0.2150
# 6       0.001266        0.000267              53.375000         0.2100
# 7       0.001288        0.000296              33.000000         0.2300
# 8       0.001420        0.000269              28.360000         0.1900
# 9       0.001252        0.000201              22.243333         0.1600
# 10      0.000965        0.000145              19.670000         0.1500
# 11      0.001777        0.000267              20.740000         0.1500
# 12      0.001622        0.000264              24.457500         0.1625
# 13      0.001724        0.000327              28.500000         0.1900
#
#     Shear_Modulus  Radians  UCS_(Mpa)  Cohesion  Friction_Angle
# 0       15.238100     0.00  57.472000     15.22           37.89
# 1       14.880680     0.26  50.884000     14.10           36.73
# 2       15.599160     0.52  42.114000     11.31           33.06
# 3       16.904075     0.79  48.567500     11.68           34.95
# 4       18.756833     1.05  48.950000     10.27           35.49
# 5       20.569550     1.31  61.342500     15.66           36.54
# 6       22.066475     1.57  67.462500     16.86           36.76
# 7       13.415233     0.00  42.506667     11.94           28.09
# 8       11.918500     0.26  40.293333     11.61           28.36
# 9        9.585367     0.52  28.026667      9.08           23.78
# 10       8.552567     0.79  18.983333      8.29           24.24
# 11       9.019733     1.05  36.830000      9.24           27.81
# 12      10.523450     1.31  39.602500     12.15           31.46
# 13      11.975367     1.57  49.133333     12.52           30.32
#
# [14 rows x 23 columns]
#
# Mean dataframe shape:
# (14, 23)
#
# Augen Gneiss mean data:
# Empty DataFrame
# Columns: [SN, Rock_type, Angle, Diameter_mm, Thickness_mm, H/D_ratio, Area_mm^2, Volume_mm^3, Bulk_Density, Porosity_percent, Density, Load_(KN), Tensile_strength_Mpa, Mass, Axial_strain, Lateral_strain, Modulus_of_Elasticity, Poisson_Ratio, Shear_Modulus, Radians, UCS_(Mpa), Cohesion, Friction_Angle]
# Index: []
#
# [0 rows x 23 columns]
#
# Psammitic Schist mean data:
# Empty DataFrame
# Columns: [SN, Rock_type, Angle, Diameter_mm, Thickness_mm, H/D_ratio, Area_mm^2, Volume_mm^3, Bulk_Density, Porosity_percent, Density, Load_(KN), Tensile_strength_Mpa, Mass, Axial_strain, Lateral_strain, Modulus_of_Elasticity, Poisson_Ratio, Shear_Modulus, Radians, UCS_(Mpa), Cohesion, Friction_Angle]
# Index: []
#
# [0 rows x 23 columns]
#
# Number of Augen Gneiss mean rows: 0
# Number of Psammitic Schist mean rows: 0
#
# Mean data successfully saved to: tensile_samples_data.csv
